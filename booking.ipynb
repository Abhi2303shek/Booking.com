# %%
import pandas as pd

# %%
bookings = pd.read_csv('bookings.csv', sep=',')
bookings
# Out:
#       Unnamed: 0                                              hotel  \
# 0              0                   Krabi La Playa Resort - SHA Plus
# 1              1                        KC Beach Club & Pool Villas
# 2              2                       Rawai VIP Villas & Kids Park
# 3              3                    FuramaXclusive Sathorn, Bangkok
# 4              4                  Bo Phut Resort and Spa - SHA Plus
# ...          ...                                                ...
# 3460        3460                                     Circular House
# 3461        3461                           Beary Best! Kampong Glam
# 3462        3462              Ambassador Transit Hotel - Terminal 2
# 3463        3463                              K2 Guesthouse Central
# 3464        3464  Heritage Collection on Boat Quay - Quayside Wi...
#
#                            location  rating        review  no_of_reviews  \
# 0                     Ao Nang Beach     8.2     Very Good          141.0
# ...

# %%
bookings['room_score'] = bookings['room_score'].fillna(0)

# %%
bookings
# Out:
#       Unnamed: 0                                              hotel  \
# 0              0                   Krabi La Playa Resort - SHA Plus
# 1              1                        KC Beach Club & Pool Villas
# 2              2                       Rawai VIP Villas & Kids Park
# 3              3                    FuramaXclusive Sathorn, Bangkok
# 4              4                  Bo Phut Resort and Spa - SHA Plus
# ...          ...                                                ...
# 3460        3460                                     Circular House
# 3461        3461                           Beary Best! Kampong Glam
# 3462        3462              Ambassador Transit Hotel - Terminal 2
# 3463        3463                              K2 Guesthouse Central
# 3464        3464  Heritage Collection on Boat Quay - Quayside Wi...
#
#                            location  rating        review  no_of_reviews  \
# 0                     Ao Nang Beach     8.2     Very Good          141.0
# ...

# %%
bookings['price'] = bookings['price']*0.75

# %%
bookings['price']
# Out:
# 0       109519.50
# 1       161478.00
# 2       326538.00
# 3       109680.00
# 4       465804.00
#           ...
# 3460    157258.50
# 3461     89034.00
# 3462    882855.00
# 3463    170551.50
# 3464    486602.25
# Name: price, Length: 3465, dtype: float64

# %%
bookings['hotel'] = bookings['hotel'].fillna('Unknown')

# %%
bookings
# Out:
#                                                   hotel  \
# 0                      Krabi La Playa Resort - SHA Plus
# 1                           KC Beach Club & Pool Villas
# 2                          Rawai VIP Villas & Kids Park
# 3                       FuramaXclusive Sathorn, Bangkok
# 4                     Bo Phut Resort and Spa - SHA Plus
# ...                                                 ...
# 3460                                     Circular House
# 3461                           Beary Best! Kampong Glam
# 3462              Ambassador Transit Hotel - Terminal 2
# 3463                              K2 Guesthouse Central
# 3464  Heritage Collection on Boat Quay - Quayside Wi...
#
#                            location  rating        review  no_of_reviews  \
# 0                     Ao Nang Beach     8.2     Very Good          141.0
# 1     Chaweng City Center , Chaweng     7.1          Good          193.0
# ...

# %%
bookings['rating'] = bookings['rating'].fillna(0)

# %%
bookings['review'] = bookings['review'].fillna('Zero')

# %%
bookings['no_of_reviews'] = bookings['no_of_reviews'].fillna(0)

# %%
bookings['room_category'] = bookings['room_category'].fillna('Unknown')

# %%
bookings['room_score'] = bookings['room_score'].fillna(0)

# %%
bookings['bed_type'] = bookings['bed_type'].fillna('Unknown')

# %%
bookings['bed_type'].hasnans
# Out:
# False

# %%
bookings.to_csv('bookings.csv')
